# %% [markdown]
# <a href="https://colab.research.google.com/github/suman-max10/false_9/blob/main/Movie_Recomm_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
movies_data = pd.read_csv('/content/drive/MyDrive/movies_recom/movies.csv')
movies_data.head()
# Out:
#    index     budget                                    genres  \
# 0      0  237000000  Action Adventure Fantasy Science Fiction
# 1      1  300000000                  Adventure Fantasy Action
# 2      2  245000000                    Action Adventure Crime
# 3      3  250000000               Action Crime Drama Thriller
# 4      4  260000000          Action Adventure Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
# ...

# %%
movies_data.nunique()
# Out:
# index                   4803
# budget                   436
# genres                  1168
# homepage                1691
# id                      4803
# keywords                4219
# original_language         37
# original_title          4801
# overview                4800
# popularity              4802
# production_companies    3697
# production_countries     469
# release_date            3280
# revenue                 3297
# runtime                  156
# spoken_languages         544
# status                     3
# tagline                 3944
# title                   4800
# vote_average              71
# vote_count              1609
# cast                    4741
# crew                    4776
# director                2349
# dtype: int64

# %%
plt.pie(movies_data['popularity'])
plt.show()

# %%
import seaborn as sns
sns.jointplot(x=movies_data['vote_average'],y=movies_data['popularity']);

# %%
sns.jointplot(x=movies_data['vote_average'],y=movies_data['popularity'],kind='kde');

# %%
sns.distplot(movies_data['popularity']);
# Out:
# <ipython-input-32-779304efa2e8>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(movies_data['popularity']);

# %%
dfx = movies_data.loc[0:4, ['popularity','vote_average']]
plt.scatter(x= dfx['popularity'], y= dfx['vote_average'])
plt.xlabel("popularity")
plt.ylabel("vote_average")
plt.title("Movie-Recomm-Scatter -Plot")
plt.legend(loc="best", labels=["popularity-vote_average"])
plt.grid(True)
# plt.xlim(50, 80)
# plt.ylim(0, 2.5)
plt.show()

# %%
dfx
# Out:
#    popularity  vote_average
# 0  150.437577           7.2
# 1  139.082615           6.9
# 2  107.376788           6.3
# 3  112.312950           7.6
# 4   43.926995           6.1

# %%
import numpy as np
import matplotlib.pyplot as plt

# Example movie data
x = movies_data['budget']
y = movies_data['popularity']

# Create a bar plot
# plt.figure(figsize=(10, 6))
plt.scatter(x[:100], y[:100], color='skyblue')

# Add labels and title
plt.xlabel('budget')
plt.ylabel('popularity')
plt.title('Movie Recommendations Based on Budget')

# Show the plot
plt.show()
